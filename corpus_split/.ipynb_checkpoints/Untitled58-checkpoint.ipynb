# %%
import pandas as pd
import numpy as np
import pdfplumber
import re
from collections import namedtuple

# %%
Line = (namedtuple('Line', 'Main_title  Keys Values'))

# %%
main = re.compile(r'(\d)\. (.*)')

# %%
under_title = re.compile(r'(\d.\d) (.*)')

# %%
key_value = re.compile(r'(.*):[\n|\s](.*)')

# %%
lines = []
with pdfplumber.open('Sledgehammer-Heat-Cure-Powder-SDS-US-20150522.pdf') as pdf:
    page = pdf.pages
    for page in pdf.pages:
        
        text = page.extract_text(x_tolerance=2, y_tolerance=1)
        #text=text.replace('· ', '').replace('  ',' ').split('\n')
        #print(text)
        for line in text.split('\n'):
            if main.search(line):
                num, Main_title = main.search(line).group(1), main.search(line).group(2)
        #if not key_value.search(line):
           # Under_title = line
            if key_value.search(line):
                Keys,Values = key_value.search(line).group(1),key_value.search(line).group(2)
            
                lines.append(Line(Main_title, Keys,Values))

# %%
print(text)
# Out:
# Sledgehammer Heat Cure Powder
# Section 16. Other information
# Key to abbreviations : ATE = Acute Toxicity Estimate
# BCF = Bioconcentration Factor
# GHS = Globally Harmonized System of Classification and Labelling of Chemicals
# IATA = International Air Transport Association
# IBC = Intermediate Bulk Container
# IMDG = International Maritime Dangerous Goods
# LogPow = logarithm of the octanol/water partition coefficient
# MARPOL 73/78 = International Convention for the Prevention of Pollution From Ships,
# 1973 as modified by the Protocol of 1978. ("Marpol" = marine pollution)
# UN = United Nations
# References : Not available.
# Indicates information that has changed from previously issued version.
# Notice to reader
# To the best of our knowledge, the information contained herein is accurate. However, neither the above-named
# supplier, nor any of its subsidiaries, assumes any liability whatsoever for the accuracy or completeness of the
# information contained herein.
# Final determination of suitability of any material is the sole responsibility of the user. All materials may present
# unknown hazards and should be used with caution. Although certain hazards are described herein, we cannot
# guarantee that these are the only hazards that exist.
# Information contained within this SDS is only to be distributed as required by law.
# Date of issue/Date of revision :5/22/2015 Date of previous issue :5/19/2015 Version :2 13/13

# %%
lines
# Out:
# [Line(Main_title='Identification', Keys='GHS product identifier ', Values='Sledgehammer Heat Cure Powder'),
#  Line(Main_title='Identification', Keys='Other means of  ', Values='Not available.'),
#  Line(Main_title='Identification', Keys='Product code ', Values='1000494-496, 1000498-500, 1000502-504, 1000543-545, 1001960-964'),
#  Line(Main_title='Identification', Keys='Product type ', Values='Powder.'),
#  Line(Main_title='Identification', Keys='Product use ', Values='Dental Products'),
#  Line(Main_title='Identification', Keys="Supplier's details ", Values='Keystone Industries'),
#  Line(Main_title='Identification', Keys='Emergency telephone  ', Values='(800) 535-5053'),
#  Line(Main_title='Hazards identification', Keys='OSHA/HCS status ', Values='This material is considered hazardous by the OSHA Hazard Communication Standard '),
#  Line(Main_title='Hazards identification', Keys='Classification of the  ', Values='COMBUSTIBLE DUSTS'),
#  Line(Main_title='Hazards identification', Keys='Percentage of the mixture consisting of ingredient(s) of unknown toxicity', Values='99%'),
#  Line(Main_title='Hazards identification', Keys='Signal word ', Values='Danger'),
#  Line(Main_title='Hazards identification', Keys='Hazard statements ', Values='May form combustible dust concentrations in air.'),
#  Line(Main_title='Hazards identification', Keys='Prevention ', Values='Obtain special instructions before use.  Do not handle until all safety precautions have '),
#  Line(Main_title='Hazards identification', Keys='Response : IF exposed or concerned', Values=' Get medical attention.'),
#  Line(Main_title='Hazards identification', Keys='Storage ', Values='Store locked up.'),
#  Line(Main_title='Hazards identification', Keys='Disposal ', Values='Dispose of contents and container in accordance with all local, regional, national and '),
#  Line(Main_title='Hazards identification', Keys='Supplemental label  ', Values='Keep container tightly closed.  Keep away from heat, hot surfaces, sparks, open flames '),
#  Line(Main_title='Hazards identification', Keys='Hazards not otherwise  ', Values='Fine dust clouds may form explosive mixtures with air.  Handling and/or processing of '),
#  Line(Main_title='Composition/information on ingredients', Keys='Substance/mixture ', Values='Mixture'),
#  Line(Main_title='Composition/information on ingredients', Keys='Other means of  ', Values='Not available.'),
#  Line(Main_title='Composition/information on ingredients', Keys='CAS number ', Values='Not applicable.'),
#  Line(Main_title='First aid measures', Keys='Eye contact ', Values='Immediately flush eyes with plenty of water, occasionally lifting the upper and lower '),
#  Line(Main_title='First aid measures', Keys='Inhalation ', Values='Remove victim to fresh air and keep at rest in a position comfortable for breathing.  If '),
#  Line(Main_title='First aid measures', Keys='Skin contact ', Values='Flush contaminated skin with plenty of water.  Remove contaminated clothing and '),
#  Line(Main_title='First aid measures', Keys='Ingestion ', Values='Wash out mouth with water.  Remove dentures if any.  Remove victim to fresh air and '),
#  Line(Main_title='First aid measures', Keys='Eye contact ', Values='Exposure to airborne concentrations above statutory or recommended exposure limits '),
#  Line(Main_title='First aid measures', Keys='Inhalation ', Values='Exposure to airborne concentrations above statutory or recommended exposure limits '),
#  Line(Main_title='First aid measures', Keys='Skin contact ', Values='No known significant effects or critical hazards.'),
#  Line(Main_title='First aid measures', Keys='Ingestion ', Values='No known significant effects or critical hazards.'),
#  Line(Main_title='First aid measures', Keys='Eye contact ', Values='Adverse symptoms may include the following:'),
#  Line(Main_title='First aid measures', Keys='Inhalation ', Values='Adverse symptoms may include the following:'),
#  Line(Main_title='First aid measures', Keys='Skin contact ', Values='Adverse symptoms may include the following:'),
#  Line(Main_title='First aid measures', Keys='Ingestion ', Values='Adverse symptoms may include the following:'),
#  Line(Main_title='First aid measures', Keys='Notes to physician ', Values='Treat symptomatically.  Contact poison treatment specialist immediately if large '),
#  Line(Main_title='First aid measures', Keys='Specific treatments ', Values='No specific treatment.'),
#  Line(Main_title='First aid measures', Keys='Protection of first-aiders ', Values='No action shall be taken involving any personal risk or without suitable training.  If it is '),
#  Line(Main_title='Fire-fighting measures', Keys='Suitable extinguishing  ', Values='Use dry chemical powder.'),
#  Line(Main_title='Fire-fighting measures', Keys='Unsuitable extinguishing  ', Values='Do not use water jet.'),
#  Line(Main_title='Fire-fighting measures', Keys='Specific hazards arising  ', Values='Fine dust clouds may form explosive mixtures with air.'),
#  Line(Main_title='Fire-fighting measures', Keys='Hazardous thermal  ', Values='Decomposition products may include the following materials:'),
#  Line(Main_title='Fire-fighting measures', Keys='Special protective actions  ', Values='Promptly isolate the scene by removing all persons from the vicinity of the incident if '),
#  Line(Main_title='Fire-fighting measures', Keys='Special protective  ', Values='Fire-fighters should wear appropriate protective equipment and self-contained breathing '),
#  Line(Main_title='Accidental release measures', Keys='For non-emergency  ', Values='No action shall be taken involving any personal risk or without suitable training.'),
#  Line(Main_title='Accidental release measures', Keys='For emergency responders ', Values='If specialised clothing is required to deal with the spillage, take note of any information '),
#  Line(Main_title='Accidental release measures', Keys='Environmental precautions ', Values='Avoid dispersal of spilled material and runoff and contact with soil, waterways, drains '),
#  Line(Main_title='Accidental release measures', Keys='Small spill ', Values='Move containers from spill area.  Use spark-proof tools and explosion-proof equipment.'),
#  Line(Main_title='Accidental release measures', Keys='Large spill ', Values='Move containers from spill area.  Use spark-proof tools and explosion-proof equipment.'),
#  Line(Main_title='Accidental release measures', Keys='waste disposal contractor.  Note', Values='see Section 1 for emergency contact information and '),
#  Line(Main_title='Handling and storage', Keys='Protective measures ', Values='Put on appropriate personal protective equipment (see Section 8).  Avoid exposure -'),
#  Line(Main_title='Handling and storage', Keys='Advice on general  ', Values='Eating, drinking and smoking should be prohibited in areas where this material is '),
#  Line(Main_title='Handling and storage', Keys='Conditions for safe storage, : Do not store above the following temperature', Values='200°C (392°F).  Store in accordance with '),
#  Line(Main_title='Exposure controls/personal protection', Keys='  TWA', Values='5 mg/m³ 8 hours.'),
#  Line(Main_title='Exposure controls/personal protection', Keys='  TWA', Values='5 mg/m³ 8 hours.'),
#  Line(Main_title='Exposure controls/personal protection', Keys='  TWA', Values='5 mg/m³ 10 hours.'),
#  Line(Main_title='Exposure controls/personal protection', Keys='  TWA', Values='5 mg/m³ 8 hours.'),
#  Line(Main_title='Exposure controls/personal protection', Keys='  TWA', Values='10 mg/m³ 8 hours.'),
#  Line(Main_title='Exposure controls/personal protection', Keys='  TWA: 10 mg/m³ 8 hours. Form', Values='Total dust'),
#  Line(Main_title='Exposure controls/personal protection', Keys='  TWA: 15 mg/m³ 8 hours. Form', Values='Total dust'),
#  Line(Main_title='Exposure controls/personal protection', Keys='Appropriate engineering  ', Values='Use only with adequate ventilation.  If user operations generate dust, fumes, gas, vapor '),
#  Line(Main_title='Exposure controls/personal protection', Keys='Environmental exposure  ', Values='Emissions from ventilation or work process equipment should be checked to ensure '),
#  Line(Main_title='Exposure controls/personal protection', Keys='Hygiene measures ', Values='Wash hands, forearms and face thoroughly after handling chemical products, before '),
#  Line(Main_title='Exposure controls/personal protection', Keys='Eye/face protection ', Values='Safety eyewear complying with an approved standard should be used when a risk '),
#  Line(Main_title='Exposure controls/personal protection', Keys='the assessment indicates a higher degree of protection', Values=' safety glasses with side-'),
#  Line(Main_title='Exposure controls/personal protection', Keys='Hand protection ', Values='Chemical-resistant, impervious gloves complying with an approved standard should be '),
#  Line(Main_title='Exposure controls/personal protection', Keys='Body protection ', Values='Personal protective equipment for the body should be selected based on the task being '),
#  Line(Main_title='Exposure controls/personal protection', Keys='Other skin protection ', Values='Appropriate footwear and any additional skin protection measures should be selected '),
#  Line(Main_title='Exposure controls/personal protection', Keys='Respiratory protection ', Values='Use a properly fitted, particulate filter respirator complying with an approved standard if '),
#  Line(Main_title='Physical and chemical properties', Keys='Physical state ', Values='Solid. [Powder.]'),
#  Line(Main_title='Physical and chemical properties', Keys='Color ', Values='Colored'),
#  Line(Main_title='Physical and chemical properties', Keys='Odor ', Values='Faint odor. [Slight]'),
#  Line(Main_title='Physical and chemical properties', Keys='pH ', Values='Not applicable.'),
#  Line(Main_title='Physical and chemical properties', Keys='Melting point ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Boiling point ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Flash point : Closed cup', Values='304°C (579.2°F) [Tagliabue.]'),
#  Line(Main_title='Physical and chemical properties', Keys='Lower and upper explosive  ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Vapor pressure ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Vapor density ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Relative density ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Solubility : Insoluble in the following materials', Values='cold water and hot water.'),
#  Line(Main_title='Physical and chemical properties', Keys='Solubility in water ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Partition coefficient: n- ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Auto-ignition temperature ', Values='Not available.'),
#  Line(Main_title='Physical and chemical properties', Keys='Decomposition temperature ', Values='200°C (392°F)'),
#  Line(Main_title='Physical and chemical properties', Keys='Viscosity ', Values='Not available.'),
#  Line(Main_title='Stability and reactivity', Keys='Reactivity ', Values='No specific test data related to reactivity available for this product or its ingredients.'),
#  Line(Main_title='Stability and reactivity', Keys='Chemical stability ', Values='The product is stable.'),
#  Line(Main_title='Stability and reactivity', Keys='Possibility of hazardous  ', Values='Under normal conditions of storage and use, hazardous reactions will not occur.'),
#  Line(Main_title='Stability and reactivity', Keys='Conditions to avoid ', Values='Avoid the creation of dust when handling and avoid all possible sources of ignition '),
#  Line(Main_title='Stability and reactivity', Keys='Incompatible materials ', Values='Reactive or incompatible with the following materials:'),
#  Line(Main_title='Stability and reactivity', Keys='Hazardous decomposition  ', Values='Under normal conditions of storage and use, hazardous decomposition products should '),
#  Line(Main_title='Toxicological information', Keys='Information on the likely  ', Values='Not available.'),
#  Line(Main_title='Toxicological information', Keys='Eye contact ', Values='Exposure to airborne concentrations above statutory or recommended exposure limits '),
#  Line(Main_title='Toxicological information', Keys='Inhalation ', Values='Exposure to airborne concentrations above statutory or recommended exposure limits '),
#  Line(Main_title='Toxicological information', Keys='Skin contact ', Values='No known significant effects or critical hazards.'),
#  Line(Main_title='Toxicological information', Keys='Ingestion ', Values='No known significant effects or critical hazards.'),
#  Line(Main_title='Toxicological information', Keys='Eye contact ', Values='Adverse symptoms may include the following:'),
#  Line(Main_title='Toxicological information', Keys='Inhalation ', Values='Adverse symptoms may include the following:'),
#  Line(Main_title='Toxicological information', Keys='Skin contact ', Values='Adverse symptoms may include the following:'),
#  Line(Main_title='Toxicological information', Keys='Ingestion ', Values='Adverse symptoms may include the following:'),
#  Line(Main_title='Toxicological information', Keys='Potential immediate  ', Values='Not available.'),
#  Line(Main_title='Toxicological information', Keys='Potential delayed effects ', Values='Not available.'),
#  Line(Main_title='Toxicological information', Keys='Potential immediate  ', Values='Not available.'),
#  Line(Main_title='Toxicological information', Keys='Potential delayed effects ', Values='Not available.'),
#  Line(Main_title='Toxicological information', Keys='General ', Values='Repeated or prolonged inhalation of dust may lead to chronic respiratory irritation.'),
#  Line(Main_title='Toxicological information', Keys='Carcinogenicity ', Values='Suspected of causing cancer.  Risk of cancer depends on duration and level of '),
#  Line(Main_title='Toxicological information', Keys='Mutagenicity ', Values='No known significant effects or critical hazards.'),
#  Line(Main_title='Toxicological information', Keys='Teratogenicity ', Values='May damage the unborn child.'),
#  Line(Main_title='Toxicological information', Keys='Developmental effects ', Values='No known significant effects or critical hazards.'),
#  Line(Main_title='Toxicological information', Keys='Fertility effects ', Values='Suspected of damaging fertility.'),
#  Line(Main_title='Ecological information', Keys='Soil/water partition  ', Values='Not available.'),
#  Line(Main_title='Ecological information', Keys='Other adverse effects ', Values='No known significant effects or critical hazards.'),
#  Line(Main_title='Disposal considerations', Keys='Disposal methods ', Values='The generation of waste should be avoided or minimized wherever possible.  Disposal '),
#  Line(Main_title='and 4.1.1.4 to  1.1 and 5.0.2.8.', Keys='Special precautions for user : Transport within user’s premises', Values='always transport in closed containers that are '),
#  Line(Main_title='and 4.1.1.4 to  1.1 and 5.0.2.8.', Keys='Transport in bulk according  ', Values='Not available.'),
#  Line(Main_title='Regulatory information', Keys='U.S. Federal regulations : TSCA 8(a) CDR Exempt/Partial exemption', Values='Not determined'),
#  Line(Main_title='Regulatory information', Keys='United States inventory (TSCA 8b)', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='Clean Water Act (CWA) 307', Values='dibutyl phthalate'),
#  Line(Main_title='Regulatory information', Keys='Clean Water Act (CWA) 311', Values='dibutyl phthalate'),
#  Line(Main_title='Regulatory information', Keys='Clean Air Act  Section 112 ', Values='Listed'),
#  Line(Main_title='Regulatory information', Keys='Clean Air Act Section 602  ', Values='Not listed'),
#  Line(Main_title='Regulatory information', Keys='Clean Air Act Section 602  ', Values='Not listed'),
#  Line(Main_title='Regulatory information', Keys='DEA List I Chemicals  ', Values='Not listed'),
#  Line(Main_title='Regulatory information', Keys='DEA List II Chemicals  ', Values='Not listed'),
#  Line(Main_title='Regulatory information', Keys='SARA 304 RQ ', Values='Not applicable.'),
#  Line(Main_title='Regulatory information', Keys='Classification ', Values='Not applicable.'),
#  Line(Main_title='Regulatory information', Keys='Massachusetts : The following components are listed', Values='DIBUTYL PHTHALATE'),
#  Line(Main_title='Regulatory information', Keys='New York : The following components are listed', Values='Di-n-butyl phthalate; 1,2-Benzenedicarboxylic acid,'),
#  Line(Main_title='Regulatory information', Keys='New Jersey : The following components are listed', Values='DI-N-BUTYL PHTHALATE; 1,'),
#  Line(Main_title='Regulatory information', Keys='Pennsylvania : The following components are listed', Values='1,2-BENZENEDICARBOXYLIC ACID, DIBUTYL '),
#  Line(Main_title='Regulatory information', Keys='WARNING', Values='This product contains a chemical known to the State of California to cause cancer and birth defects or other '),
#  Line(Main_title='Regulatory information', Keys='Canada inventory ', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='International lists : Australia inventory (AICS)', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='China inventory (IECSC)', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='Japan inventory', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='Korea inventory', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='Malaysia Inventory (EHS Register)', Values='Not determined.'),
#  Line(Main_title='Regulatory information', Keys='New Zealand Inventory of Chemicals (NZIoC)', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='Philippines inventory (PICCS)', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='Taiwan inventory (CSNN)', Values='All components are listed or exempted.'),
#  Line(Main_title='Regulatory information', Keys='Chemical Weapons  ', Values='Not listed'),
#  Line(Main_title='Regulatory information', Keys='Chemical Weapons  ', Values='Not listed'),
#  Line(Main_title='Regulatory information', Keys='Chemical Weapons  ', Values='Not listed'),
#  Line(Main_title='Other information', Keys='Caution', Values='HMIS® ratings are based on a 0-4 rating scale, with 0 representing minimal hazards or risks, and 4 '),
#  Line(Main_title='This warning system is intended to ', Keys='Date of printing ', Values='5/22/2015'),
#  Line(Main_title='This warning system is intended to ', Keys='Date of issue/Date of  ', Values='5/22/2015'),
#  Line(Main_title='This warning system is intended to ', Keys='Date of previous issue ', Values='5/19/2015'),
#  Line(Main_title='This warning system is intended to ', Keys='Version ', Values='2'),
#  Line(Main_title='Other information', Keys='Key to abbreviations ', Values='ATE = Acute Toxicity Estimate'),
#  Line(Main_title='("Marpol" = marine pollution)', Keys='References ', Values='Not available.')]

# %%
df = pd.DataFrame(lines)
df
# Out:
#                               Main_title                     Keys  \
# 0                         Identification  GHS product identifier
# 1                         Identification         Other means of
# 2                         Identification            Product code
# 3                         Identification            Product type
# 4                         Identification             Product use
# ..                                   ...                      ...
# 144  This warning system is intended to   Date of issue/Date of
# 145  This warning system is intended to   Date of previous issue
# 146  This warning system is intended to                  Version
# 147                    Other information    Key to abbreviations
# 148        ("Marpol" = marine pollution)              References
#
#                                                 Values
# 0                        Sledgehammer Heat Cure Powder
# 1                                       Not available.
# 2    1000494-496, 1000498-500, 1000502-504, 1000543...
# 3                                              Powder.
# 4                                      Dental Products
# ..                                                 ...
# 144                                          5/22/2015
# 145                                          5/19/2015
# 146                                                  2
# 147                      ATE = Acute Toxicity Estimate
# 148                                     Not available.
#
# [149 rows x 3 columns]

# %%
for line in lines:
    print(line._asdict())
# Out:
# {'Main_title': 'Identification', 'Keys': 'GHS product identifier ', 'Values': 'Sledgehammer Heat Cure Powder'}
# {'Main_title': 'Identification', 'Keys': 'Other means of  ', 'Values': 'Not available.'}
# {'Main_title': 'Identification', 'Keys': 'Product code ', 'Values': '1000494-496, 1000498-500, 1000502-504, 1000543-545, 1001960-964'}
# {'Main_title': 'Identification', 'Keys': 'Product type ', 'Values': 'Powder.'}
# {'Main_title': 'Identification', 'Keys': 'Product use ', 'Values': 'Dental Products'}
# {'Main_title': 'Identification', 'Keys': "Supplier's details ", 'Values': 'Keystone Industries'}
# {'Main_title': 'Identification', 'Keys': 'Emergency telephone  ', 'Values': '(800) 535-5053'}
# {'Main_title': 'Hazards identification', 'Keys': 'OSHA/HCS status ', 'Values': 'This material is considered hazardous by the OSHA Hazard Communication Standard '}
# {'Main_title': 'Hazards identification', 'Keys': 'Classification of the  ', 'Values': 'COMBUSTIBLE DUSTS'}
# {'Main_title': 'Hazards identification', 'Keys': 'Percentage of the mixture consisting of ingredient(s) of unknown toxicity', 'Values': '99%'}
# {'Main_title': 'Hazards identification', 'Keys': 'Signal word ', 'Values': 'Danger'}
# {'Main_title': 'Hazards identification', 'Keys': 'Hazard statements ', 'Values': 'May form combustible dust concentrations in air.'}
# {'Main_title': 'Hazards identification', 'Keys': 'Prevention ', 'Values': 'Obtain special instructions before use.  Do not handle until all safety precautions have '}
# {'Main_title': 'Hazards identification', 'Keys': 'Response : IF exposed or concerned', 'Values': ' Get medical attention.'}
# {'Main_title': 'Hazards identification', 'Keys': 'Storage ', 'Values': 'Store locked up.'}
# {'Main_title': 'Hazards identification', 'Keys': 'Disposal ', 'Values': 'Dispose of contents and container in accordance with all local, regional, national and '}
# {'Main_title': 'Hazards identification', 'Keys': 'Supplemental label  ', 'Values': 'Keep container tightly closed.  Keep away from heat, hot surfaces, sparks, open flames '}
# {'Main_title': 'Hazards identification', 'Keys': 'Hazards not otherwise  ', 'Values': 'Fine dust clouds may form explosive mixtures with air.  Handling and/or processing of '}
# {'Main_title': 'Composition/information on ingredients', 'Keys': 'Substance/mixture ', 'Values': 'Mixture'}
# {'Main_title': 'Composition/information on ingredients', 'Keys': 'Other means of  ', 'Values': 'Not available.'}
# {'Main_title': 'Composition/information on ingredients', 'Keys': 'CAS number ', 'Values': 'Not applicable.'}
# {'Main_title': 'First aid measures', 'Keys': 'Eye contact ', 'Values': 'Immediately flush eyes with plenty of water, occasionally lifting the upper and lower '}
# {'Main_title': 'First aid measures', 'Keys': 'Inhalation ', 'Values': 'Remove victim to fresh air and keep at rest in a position comfortable for breathing.  If '}
# {'Main_title': 'First aid measures', 'Keys': 'Skin contact ', 'Values': 'Flush contaminated skin with plenty of water.  Remove contaminated clothing and '}
# {'Main_title': 'First aid measures', 'Keys': 'Ingestion ', 'Values': 'Wash out mouth with water.  Remove dentures if any.  Remove victim to fresh air and '}
# {'Main_title': 'First aid measures', 'Keys': 'Eye contact ', 'Values': 'Exposure to airborne concentrations above statutory or recommended exposure limits '}
# {'Main_title': 'First aid measures', 'Keys': 'Inhalation ', 'Values': 'Exposure to airborne concentrations above statutory or recommended exposure limits '}
# {'Main_title': 'First aid measures', 'Keys': 'Skin contact ', 'Values': 'No known significant effects or critical hazards.'}
# {'Main_title': 'First aid measures', 'Keys': 'Ingestion ', 'Values': 'No known significant effects or critical hazards.'}
# {'Main_title': 'First aid measures', 'Keys': 'Eye contact ', 'Values': 'Adverse symptoms may include the following:'}
# {'Main_title': 'First aid measures', 'Keys': 'Inhalation ', 'Values': 'Adverse symptoms may include the following:'}
# {'Main_title': 'First aid measures', 'Keys': 'Skin contact ', 'Values': 'Adverse symptoms may include the following:'}
# {'Main_title': 'First aid measures', 'Keys': 'Ingestion ', 'Values': 'Adverse symptoms may include the following:'}
# {'Main_title': 'First aid measures', 'Keys': 'Notes to physician ', 'Values': 'Treat symptomatically.  Contact poison treatment specialist immediately if large '}
# {'Main_title': 'First aid measures', 'Keys': 'Specific treatments ', 'Values': 'No specific treatment.'}
# {'Main_title': 'First aid measures', 'Keys': 'Protection of first-aiders ', 'Values': 'No action shall be taken involving any personal risk or without suitable training.  If it is '}
# {'Main_title': 'Fire-fighting measures', 'Keys': 'Suitable extinguishing  ', 'Values': 'Use dry chemical powder.'}
# {'Main_title': 'Fire-fighting measures', 'Keys': 'Unsuitable extinguishing  ', 'Values': 'Do not use water jet.'}
# {'Main_title': 'Fire-fighting measures', 'Keys': 'Specific hazards arising  ', 'Values': 'Fine dust clouds may form explosive mixtures with air.'}
# {'Main_title': 'Fire-fighting measures', 'Keys': 'Hazardous thermal  ', 'Values': 'Decomposition products may include the following materials:'}
# {'Main_title': 'Fire-fighting measures', 'Keys': 'Special protective actions  ', 'Values': 'Promptly isolate the scene by removing all persons from the vicinity of the incident if '}
# {'Main_title': 'Fire-fighting measures', 'Keys': 'Special protective  ', 'Values': 'Fire-fighters should wear appropriate protective equipment and self-contained breathing '}
# {'Main_title': 'Accidental release measures', 'Keys': 'For non-emergency  ', 'Values': 'No action shall be taken involving any personal risk or without suitable training.'}
# {'Main_title': 'Accidental release measures', 'Keys': 'For emergency responders ', 'Values': 'If specialised clothing is required to deal with the spillage, take note of any information '}
# {'Main_title': 'Accidental release measures', 'Keys': 'Environmental precautions ', 'Values': 'Avoid dispersal of spilled material and runoff and contact with soil, waterways, drains '}
# {'Main_title': 'Accidental release measures', 'Keys': 'Small spill ', 'Values': 'Move containers from spill area.  Use spark-proof tools and explosion-proof equipment.'}
# {'Main_title': 'Accidental release measures', 'Keys': 'Large spill ', 'Values': 'Move containers from spill area.  Use spark-proof tools and explosion-proof equipment.'}
# {'Main_title': 'Accidental release measures', 'Keys': 'waste disposal contractor.  Note', 'Values': 'see Section 1 for emergency contact information and '}
# {'Main_title': 'Handling and storage', 'Keys': 'Protective measures ', 'Values': 'Put on appropriate personal protective equipment (see Section 8).  Avoid exposure -'}
# {'Main_title': 'Handling and storage', 'Keys': 'Advice on general  ', 'Values': 'Eating, drinking and smoking should be prohibited in areas where this material is '}
# {'Main_title': 'Handling and storage', 'Keys': 'Conditions for safe storage, : Do not store above the following temperature', 'Values': '200°C (392°F).  Store in accordance with '}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': '  TWA', 'Values': '5 mg/m³ 8 hours.'}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': '  TWA', 'Values': '5 mg/m³ 8 hours.'}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': '  TWA', 'Values': '5 mg/m³ 10 hours.'}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': '  TWA', 'Values': '5 mg/m³ 8 hours.'}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': '  TWA', 'Values': '10 mg/m³ 8 hours.'}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': '  TWA: 10 mg/m³ 8 hours. Form', 'Values': 'Total dust'}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': '  TWA: 15 mg/m³ 8 hours. Form', 'Values': 'Total dust'}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'Appropriate engineering  ', 'Values': 'Use only with adequate ventilation.  If user operations generate dust, fumes, gas, vapor '}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'Environmental exposure  ', 'Values': 'Emissions from ventilation or work process equipment should be checked to ensure '}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'Hygiene measures ', 'Values': 'Wash hands, forearms and face thoroughly after handling chemical products, before '}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'Eye/face protection ', 'Values': 'Safety eyewear complying with an approved standard should be used when a risk '}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'the assessment indicates a higher degree of protection', 'Values': ' safety glasses with side-'}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'Hand protection ', 'Values': 'Chemical-resistant, impervious gloves complying with an approved standard should be '}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'Body protection ', 'Values': 'Personal protective equipment for the body should be selected based on the task being '}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'Other skin protection ', 'Values': 'Appropriate footwear and any additional skin protection measures should be selected '}
# {'Main_title': 'Exposure controls/personal protection', 'Keys': 'Respiratory protection ', 'Values': 'Use a properly fitted, particulate filter respirator complying with an approved standard if '}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Physical state ', 'Values': 'Solid. [Powder.]'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Color ', 'Values': 'Colored'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Odor ', 'Values': 'Faint odor. [Slight]'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'pH ', 'Values': 'Not applicable.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Melting point ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Boiling point ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Flash point : Closed cup', 'Values': '304°C (579.2°F) [Tagliabue.]'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Lower and upper explosive  ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Vapor pressure ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Vapor density ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Relative density ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Solubility : Insoluble in the following materials', 'Values': 'cold water and hot water.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Solubility in water ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Partition coefficient: n- ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Auto-ignition temperature ', 'Values': 'Not available.'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Decomposition temperature ', 'Values': '200°C (392°F)'}
# {'Main_title': 'Physical and chemical properties', 'Keys': 'Viscosity ', 'Values': 'Not available.'}
# {'Main_title': 'Stability and reactivity', 'Keys': 'Reactivity ', 'Values': 'No specific test data related to reactivity available for this product or its ingredients.'}
# {'Main_title': 'Stability and reactivity', 'Keys': 'Chemical stability ', 'Values': 'The product is stable.'}
# {'Main_title': 'Stability and reactivity', 'Keys': 'Possibility of hazardous  ', 'Values': 'Under normal conditions of storage and use, hazardous reactions will not occur.'}
# {'Main_title': 'Stability and reactivity', 'Keys': 'Conditions to avoid ', 'Values': 'Avoid the creation of dust when handling and avoid all possible sources of ignition '}
# {'Main_title': 'Stability and reactivity', 'Keys': 'Incompatible materials ', 'Values': 'Reactive or incompatible with the following materials:'}
# {'Main_title': 'Stability and reactivity', 'Keys': 'Hazardous decomposition  ', 'Values': 'Under normal conditions of storage and use, hazardous decomposition products should '}
# {'Main_title': 'Toxicological information', 'Keys': 'Information on the likely  ', 'Values': 'Not available.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Eye contact ', 'Values': 'Exposure to airborne concentrations above statutory or recommended exposure limits '}
# {'Main_title': 'Toxicological information', 'Keys': 'Inhalation ', 'Values': 'Exposure to airborne concentrations above statutory or recommended exposure limits '}
# {'Main_title': 'Toxicological information', 'Keys': 'Skin contact ', 'Values': 'No known significant effects or critical hazards.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Ingestion ', 'Values': 'No known significant effects or critical hazards.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Eye contact ', 'Values': 'Adverse symptoms may include the following:'}
# {'Main_title': 'Toxicological information', 'Keys': 'Inhalation ', 'Values': 'Adverse symptoms may include the following:'}
# {'Main_title': 'Toxicological information', 'Keys': 'Skin contact ', 'Values': 'Adverse symptoms may include the following:'}
# {'Main_title': 'Toxicological information', 'Keys': 'Ingestion ', 'Values': 'Adverse symptoms may include the following:'}
# {'Main_title': 'Toxicological information', 'Keys': 'Potential immediate  ', 'Values': 'Not available.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Potential delayed effects ', 'Values': 'Not available.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Potential immediate  ', 'Values': 'Not available.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Potential delayed effects ', 'Values': 'Not available.'}
# {'Main_title': 'Toxicological information', 'Keys': 'General ', 'Values': 'Repeated or prolonged inhalation of dust may lead to chronic respiratory irritation.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Carcinogenicity ', 'Values': 'Suspected of causing cancer.  Risk of cancer depends on duration and level of '}
# {'Main_title': 'Toxicological information', 'Keys': 'Mutagenicity ', 'Values': 'No known significant effects or critical hazards.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Teratogenicity ', 'Values': 'May damage the unborn child.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Developmental effects ', 'Values': 'No known significant effects or critical hazards.'}
# {'Main_title': 'Toxicological information', 'Keys': 'Fertility effects ', 'Values': 'Suspected of damaging fertility.'}
# {'Main_title': 'Ecological information', 'Keys': 'Soil/water partition  ', 'Values': 'Not available.'}
# {'Main_title': 'Ecological information', 'Keys': 'Other adverse effects ', 'Values': 'No known significant effects or critical hazards.'}
# {'Main_title': 'Disposal considerations', 'Keys': 'Disposal methods ', 'Values': 'The generation of waste should be avoided or minimized wherever possible.  Disposal '}
# {'Main_title': 'and 4.1.1.4 to  1.1 and 5.0.2.8.', 'Keys': 'Special precautions for user : Transport within user’s premises', 'Values': 'always transport in closed containers that are '}
# {'Main_title': 'and 4.1.1.4 to  1.1 and 5.0.2.8.', 'Keys': 'Transport in bulk according  ', 'Values': 'Not available.'}
# {'Main_title': 'Regulatory information', 'Keys': 'U.S. Federal regulations : TSCA 8(a) CDR Exempt/Partial exemption', 'Values': 'Not determined'}
# {'Main_title': 'Regulatory information', 'Keys': 'United States inventory (TSCA 8b)', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Clean Water Act (CWA) 307', 'Values': 'dibutyl phthalate'}
# {'Main_title': 'Regulatory information', 'Keys': 'Clean Water Act (CWA) 311', 'Values': 'dibutyl phthalate'}
# {'Main_title': 'Regulatory information', 'Keys': 'Clean Air Act  Section 112 ', 'Values': 'Listed'}
# {'Main_title': 'Regulatory information', 'Keys': 'Clean Air Act Section 602  ', 'Values': 'Not listed'}
# {'Main_title': 'Regulatory information', 'Keys': 'Clean Air Act Section 602  ', 'Values': 'Not listed'}
# {'Main_title': 'Regulatory information', 'Keys': 'DEA List I Chemicals  ', 'Values': 'Not listed'}
# {'Main_title': 'Regulatory information', 'Keys': 'DEA List II Chemicals  ', 'Values': 'Not listed'}
# {'Main_title': 'Regulatory information', 'Keys': 'SARA 304 RQ ', 'Values': 'Not applicable.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Classification ', 'Values': 'Not applicable.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Massachusetts : The following components are listed', 'Values': 'DIBUTYL PHTHALATE'}
# {'Main_title': 'Regulatory information', 'Keys': 'New York : The following components are listed', 'Values': 'Di-n-butyl phthalate; 1,2-Benzenedicarboxylic acid,'}
# {'Main_title': 'Regulatory information', 'Keys': 'New Jersey : The following components are listed', 'Values': 'DI-N-BUTYL PHTHALATE; 1,'}
# {'Main_title': 'Regulatory information', 'Keys': 'Pennsylvania : The following components are listed', 'Values': '1,2-BENZENEDICARBOXYLIC ACID, DIBUTYL '}
# {'Main_title': 'Regulatory information', 'Keys': 'WARNING', 'Values': 'This product contains a chemical known to the State of California to cause cancer and birth defects or other '}
# {'Main_title': 'Regulatory information', 'Keys': 'Canada inventory ', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'International lists : Australia inventory (AICS)', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'China inventory (IECSC)', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Japan inventory', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Korea inventory', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Malaysia Inventory (EHS Register)', 'Values': 'Not determined.'}
# {'Main_title': 'Regulatory information', 'Keys': 'New Zealand Inventory of Chemicals (NZIoC)', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Philippines inventory (PICCS)', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Taiwan inventory (CSNN)', 'Values': 'All components are listed or exempted.'}
# {'Main_title': 'Regulatory information', 'Keys': 'Chemical Weapons  ', 'Values': 'Not listed'}
# {'Main_title': 'Regulatory information', 'Keys': 'Chemical Weapons  ', 'Values': 'Not listed'}
# {'Main_title': 'Regulatory information', 'Keys': 'Chemical Weapons  ', 'Values': 'Not listed'}
# {'Main_title': 'Other information', 'Keys': 'Caution', 'Values': 'HMIS® ratings are based on a 0-4 rating scale, with 0 representing minimal hazards or risks, and 4 '}
# {'Main_title': 'This warning system is intended to ', 'Keys': 'Date of printing ', 'Values': '5/22/2015'}
# {'Main_title': 'This warning system is intended to ', 'Keys': 'Date of issue/Date of  ', 'Values': '5/22/2015'}
# {'Main_title': 'This warning system is intended to ', 'Keys': 'Date of previous issue ', 'Values': '5/19/2015'}
# {'Main_title': 'This warning system is intended to ', 'Keys': 'Version ', 'Values': '2'}
# {'Main_title': 'Other information', 'Keys': 'Key to abbreviations ', 'Values': 'ATE = Acute Toxicity Estimate'}
# {'Main_title': '("Marpol" = marine pollution)', 'Keys': 'References ', 'Values': 'Not available.'}

# %%
import json
with open('pdf_1_nested.json', 'w') as fp:
    json.dump(lines, fp)

# %%
def recur_dictify(frame):
    if len(frame.columns) == 1:
        if frame.values.size == 1: return frame.values[0][0]
        return frame.values.squeeze()
    grouped = frame.groupby(frame.columns[0])
    d = {k: recur_dictify(g.iloc[:,1:]) for k,g in grouped}
    return d
nested_dic = recur_dictify(df)
with open('pdf_1_nested.json', 'w') as fp:
    json.dump(nested_dic, fp)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-1b850ac13a57> in <module>
#       8 nested_dic = recur_dictify(df)
#       9 with open('pdf_1_nested.json', 'w') as fp:
# ---> 10     json.dump(nested_dic, fp)
#
# ~\.conda\envs\House\lib\json\__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~\.conda\envs\House\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# ~\.conda\envs\House\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~\.conda\envs\House\lib\json\encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~\.conda\envs\House\lib\json\encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# ~\.conda\envs\House\lib\json\encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type ndarray is not JSON serializable
